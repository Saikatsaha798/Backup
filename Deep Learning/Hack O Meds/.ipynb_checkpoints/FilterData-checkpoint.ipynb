# %%
import os

# %%
train_path = r"Data/train"
test_path = r"Data/test"
valid_path = r"Data/valid"

# %%
c = 0
for data_types in os.listdir(train_path):
    c = 1
    for data in os.listdir(f"{train_path}//{data_types}"):
#         print(data)
        if ("adenocarcinoma" in data_types):
            name = "ac"
        elif ("large" in data_types):
            name = "lc"
        elif ("squamous" in data_types):
            name = "sc"
        else:
            name = "no"
        
        os.rename(f"{train_path}//{data_types}//{data}", f"{train_path}//{data_types}//{name}_{c}.png")
        c+=1
    print(f"{data_types} : {c}")
# Out:
# adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib : 196
# large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa : 116
# normal : 149
# squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa : 156

# %%
c = 0
for data_types in os.listdir(test_path):
    c = 0
    for data in os.listdir(f"{test_path}//{data_types}"):
#         print(data)
        if ("adenocarcinoma" in data_types):
            name = "ac"
        elif ("large" in data_types):
            name = "lc"
        elif ("squamous" in data_types):
            name = "sc"
        else:
            name = "no"
        
        os.rename(f"{test_path}//{data_types}//{data}", f"{test_path}//{data_types}//{name}_{c}.png")
        c+=1
    print(f"{data_types} : {c}")
# Out:
# adenocarcinoma : 120
# large.cell.carcinoma : 51
# normal : 54
# squamous.cell.carcinoma : 90

# %%
c = 0
for data_types in os.listdir(valid_path):
    c = 0
    for data in os.listdir(f"{valid_path}//{data_types}"):
#         print(data)

        if ("adenocarcinoma" in data_types):
            name = "ac"
        elif ("large" in data_types):
            name = "lc"
        elif ("squamous" in data_types):
            name = "sc"
        else:
            name = "no"
        
        os.rename(f"{valid_path}//{data_types}//{data}", f"{valid_path}//{data_types}//{name}_{c}.png")
        c+=1
    print(f"{data_types} : {c}")
# Out:
# adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib : 23
# large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa : 21
# normal : 13
# squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa : 15

# %%
from pathlib import Path
import random
from PIL import Image

image_path = Path(train_path)

# Set seed
random.seed(42) # <- try changing this and see what happens

# 1. Get all image paths (* means "any combination")
image_path_list = list(image_path.glob("*/*.png"))
# print(image_path_list)
# 2. Get random image path
random_image_path = random.choice(image_path_list)

# 3. Get image class from path name (the image class is the name of the directory where the image is stored)
image_class = random_image_path.parent.stem

# 4. Open image
img = Image.open(random_image_path)

# 5. Print metadata
print(f"Random image path: {random_image_path}")
print(f"Image class: {image_class}")
print(f"Image height: {img.height}") 
print(f"Image width: {img.width}")
img
# Out:
# Random image path: Data\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\ac_26.png
# Image class: adenocarcinoma_left.lower
# Image height: 251
# Image width: 392
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=392x251>

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# Write transform for image
data_transform = transforms.Compose([
    # Resize the images to 512x512
    transforms.Resize(size=(512, 512)),
    # Flip the images randomly on the horizontal
    transforms.RandomHorizontalFlip(p=0.5), # p = probability of flip, 0.5 = 50% chance
    # Turn the image into a torch.Tensor
    transforms.ToTensor() # this also converts all pixel values from 0 to 255 to be between 0.0 and 1.0 
])

# %%
def plot_transformed_images(image_paths, transform, n=3, seed=42):
    """Plots a series of random images from image_paths.

    Will open n image paths from image_paths, transform them
    with transform and plot them side by side.

    Args:
        image_paths (list): List of target image paths. 
        transform (PyTorch Transforms): Transforms to apply to images.
        n (int, optional): Number of images to plot. Defaults to 3.
        seed (int, optional): Random seed for the random generator. Defaults to 42.
    """
    random.seed(seed)
    random_image_paths = random.sample(image_paths, k=n)
    for image_path in random_image_paths:
        with Image.open(image_path) as f:
            fig, ax = plt.subplots(1, 2)
            ax[0].imshow(f) 
            ax[0].set_title(f"Original \nSize: {f.size}")
            ax[0].axis("off")

            # Transform and plot image
            # Note: permute() will change shape of image to suit matplotlib 
            # (PyTorch default is [C, H, W] but Matplotlib is [H, W, C])
            transformed_image = transform(f).permute(1, 2, 0) 
            ax[1].imshow(transformed_image) 
            ax[1].set_title(f"Transformed \nSize: {transformed_image.shape}")
            ax[1].axis("off")

            fig.suptitle(f"Class: {image_path.parent.stem}", fontsize=16)

plot_transformed_images(image_path_list, 
                        transform=data_transform, 
                        n=3)

# %%
import os

# %%
import pandas as pd
data = pd.DataFrame()

# %%
def extractCSV(type):
    data = {
        "File Name" : [],
        "Adenocarcinoma" : [],
        "Large cell carcinoma" : [],
        "Squamous cell carcinoma" : []
    }
    
    exec(f"path = {type}_path")

    for data_types in os.listdir(path):
    # data_types = os.listdir(valid_path)[0]
        for datas in os.listdir(f"{path}//{data_types}"):
        #         print(data)

            if ("ac" in datas):
                data["result"].append([1, 0, 0])
            elif ("lc" in datas):
                data["result"].append([0, 1, 0])
            elif ("sc" in datas):
                data["result"].append([0, 0, 1])
            else:
                data["result"].append([0, 0, 0])

            data["File Name"].append(f"{path}//{data_types}//{datas}")
    #         print("ac" in data, "lc" in data, "sc" in data, datas)
    dataf = pd.DataFrame(data)
    dataf.to_csv(f"{type}_data.csv")

# %%
os.listdir(valid_path)[0]
# Out:
# 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'

# %%
dataf
# Out:
#                                             File Name     result
# 0   Data/valid//adenocarcinoma_left.lower.lobe_T2_...  [1, 0, 0]
# 1   Data/valid//adenocarcinoma_left.lower.lobe_T2_...  [1, 0, 0]
# 2   Data/valid//adenocarcinoma_left.lower.lobe_T2_...  [1, 0, 0]
# 3   Data/valid//adenocarcinoma_left.lower.lobe_T2_...  [1, 0, 0]
# 4   Data/valid//adenocarcinoma_left.lower.lobe_T2_...  [1, 0, 0]
# ..                                                ...        ...
# 67  Data/valid//squamous.cell.carcinoma_left.hilum...  [0, 0, 1]
# 68  Data/valid//squamous.cell.carcinoma_left.hilum...  [0, 0, 1]
# 69  Data/valid//squamous.cell.carcinoma_left.hilum...  [0, 0, 1]
# 70  Data/valid//squamous.cell.carcinoma_left.hilum...  [0, 0, 1]
# 71  Data/valid//squamous.cell.carcinoma_left.hilum...  [0, 0, 1]
#
# [72 rows x 2 columns]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\saika\\OneDrive\\Documents\\Source Code\\Deep Learning\\Hack O Meds'

# %%
dataf.iloc[0, 0]
# Out:
# 'Data/test//adenocarcinoma//ac_0.png'

# %%
import torch

# %%
torch.tensor([1,0,0])
# Out:
# tensor([1, 0, 0])
